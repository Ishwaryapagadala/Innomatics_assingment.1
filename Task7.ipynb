# %%
class A:
  def __init__(s,n,a):print(n,"is",a)
A("Bedroom Light","ON")
# Out:
# Bedroom Light is ON

# %%
class A:
  def __init__(s,n,i,d):print("Employee ID Card\nName:",n,"\nID:",i,"\nDepartment:",d)
A("Rahul","EM102","IT")
# Out:
# Employee ID Card
# Name: Rahul
# ID: EM102
# Department: IT

# %%
class A:
  def __init__(s,n,p):print("Contact Saved\nName:",n,"\nPhone:",p)
A("Anita","9876543211")
# Out:
# Contact Saved
# Name: Anita
# Phone: 9876543211

# %%
class A:
  def __init__(s,n,p):print("Product:",n,"\nPrice:  ₹"+str(p))
A("Headphones",2440)
# Out:
# Product: Headphones
# Price:  ₹2440

# %%
class A:
  def __init__(s,n,r):print("Movie:",n,"\nRating:",r,"/ 5")
A("Inception",4.8)
# Out:
# Movie: Inception
# Rating: 4.8 / 5

# %%
class A:
  def __init__(s,n,a):print("Delivery Details\nCustomer:",n,"\nAddress:",a)
A("Suman","Hyderabad")
# Out:
# Delivery Details
# Customer: Suman
# Address: Hyderabad
