# %%
sentence = input("Enter sentences:")
words = sentence.split()
unique_words=set(words)
print("Unique words count:",len(unique_words))
print("Unique words:,unique_words")
# Out:
# Enter sentences:hello welcome
# Unique words count: 2
# Unique words:,unique_words

# %%
employees= {
    "Ravi": 75000,
    "Anitha": 68000,
    "Kiran": 72000
}
highest_paid=max(employees,key=employees.get)
print("Highest Salary:",highest_paid,"_",employees[highest_paid])
# Out:
# Highest Salary: Ravi _ 75000

# %%
numbers= [ 45,22,89,10,66]
print("List:",numbers)
print("Max:",min(numbers))
# Out:
# List: [45, 22, 89, 10, 66]
# Max: 10

# %%
prices=[450,1200,899,1500,300]
print("Products above 1000:",sum(1 for price in prices if price  > 1000))
# Out:
# Products above 1000: 2

# %%
attendence = ["p","p","A","p","p"]
percentage = (attendence.count("p")/len(attendence))*100
print("Attendence percentage:",percentage)
# Out:
# Attendence percentage: 80.0

# %%
phone_numbers = [9877654321,9123456780,908765432]
print("Unique phone numbers:",set(phone_numbers))
# Out:
# Unique phone numbers: {908765432, 9877654321, 9123456780}

# %%
text = "python"
freq = {}
for ch in text:
  freq[ch] = freq.get(ch,0)+1
print(freq)
# Out:
# {'p': 1, 'y': 1, 't': 1, 'h': 1, 'o': 1, 'n': 1}

# %%
numbers = [10,20,30]
print("Tuple:",tuple(numbers))
# Out:
# Tuple: (10, 20, 30)

# %%
employees ={"Ravi":75000,"Anitha":68000}
print ("Employee exists" if "Ravi" in employees else "Employee does not exist")
# Out:
# Employee exists

# %%
marks = [70,80,65,75]
average =sum(marks)/len(marks)
print("Average Marks:",average)
# Out:
# Average Marks: 72.5
